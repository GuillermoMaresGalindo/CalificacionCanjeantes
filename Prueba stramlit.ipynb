# %%
# %pip install streamlit
# Out:
# ...
#   Using cached streamlit-1.12.0-py2.py3-none-any.whl (9.1 MB)
# ...
#   Using cached validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached importlib_metadata-4.12.0-py3-none-any.whl (21 kB)
# ...
#      ---------------------------------------- 19.5/19.5 MB 1.1 MB/s eta 0:00:00
# ...
#   Using cached typing_extensions-4.3.0-py3-none-any.whl (25 kB)
# ...
#      ------------------------------------ 903.8/903.8 KB 319.5 kB/s eta 0:00:00
# ...
#   Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# ...
#      ---------------------------------------- 14.6/14.6 MB 1.3 MB/s eta 0:00:00
# ...
#   Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# ...
#   Using cached semver-2.13.0-py2.py3-none-any.whl (12 kB)
# ...
#      ---------------------------------------- 3.3/3.3 MB 1.3 MB/s eta 0:00:00
# ...
#   Using cached pydeck-0.7.1-py2.py3-none-any.whl (4.3 MB)
# ...
#   Using cached tzlocal-4.2-py3-none-any.whl (19 kB)
# ...

# %%
import streamlit as st

x = st.slider('Select a value')
st.write(x, 'squared is', x * x)
# Out:
# 2022-08-14 14:47:10.201 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# 2022-08-14 14:47:10.585
# ...
#   command:
#
#     streamlit run c:\Users\guill\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
